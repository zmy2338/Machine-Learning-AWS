# %% [markdown]
# <a href="https://colab.research.google.com/github/zmy2338/Machine-Learning-AWS/blob/main/AWS_Part_II_Lab_Notebook_%5BSOLUTIONS%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab #6: Deep Learning with CNNs**
# ---
#
# ### **Description**
# In this week's lab you'll work through another application of image classification using Convolutional Neural Networks (CNNs). CNNs are mainly used for image/object recognition and classification.
#
# You will build a CNN model using the steps of implementing a neural net from scratch with PyTorch and fast.ai.
#
# <br>
#
# ### **Lab Structure**
#
# **Part 1**: [Classifying Alien vs. Predator](#p1)
#
# > **Part 1.1**: [Classifying Images with Deep Neural Networks](#p1.1)
#
# > **Part 1.2**: [Classifying Images with Convolutional Neural Networks](#p1.2)
#
# **Part 2**: [[ADDITIONAL PRACTICE] Chihuahua or Muffin?](#p2)
#
#
# **Part 3**: [Advanced Deep Learning Techniques](#p3)
#
# > **Part 3.1**: [Data Augmentation](#p3.1)
#
# > **Part 3.2**: [Dropout Layers](#p3.2)
#
# > **Part 3.3**: [Using Pre-Trained Models](#p3.3)
#
# **Part 4**: [[ADDITIONAL PRACTICE] Classification of Dogs and Cats](#p4)
#
#
# <br>
#
#
# ### **Goals**
# By the end of this lab, you will be able to:
# * Build and train a CNN using PyTorch and fast.ai
#
# <br>
#
# ### **Cheat Sheets**
# [Deep Learning with PyTorch for CNNs](https://docs.google.com/document/d/1oqX_N_s7oxHbsIQzWgpWJDNAE5jky5VGMDFCOFMsIYc/edit?usp=sharing)
#
# <br>
#
# **Before starting, run the code below to import all necessary functions and libraries.**

# %%
# !pip install --quiet gdown==4.5.4 --no-cache-dir
# !pip install torchsummary
from torchsummary import summary

import os
import random

import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from fastai.vision.all import *

from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torchvision
from torchvision import datasets, transforms
from torchvision.datasets import ImageFolder

from fastai.optimizer import Adam

# !gdown 15L-eqjAUFhEBPxTHlUCkgATnZptUhfjj
# !unzip -qq -n alien_or_predator.zip

device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # PyTorch v0.4.0

# %% [markdown]
# <a name="p1"></a>
#
# ---
# ## **Part 1: Classifying Alien vs. Predator**
# ---

# %% [markdown]
# <a name="p1.1"></a>
#
# ### **Part 1.1: Classifying Images with Deep Neural Networks**
# ---
#
# **Alien vs. Predator** In this section, you will build a deep neural network (DNN) model that can distinguish between pictures of Alien and pictures of Predator.
#
# ![alienbanner.png](data:image/png;base64,...)

# %% [markdown]
# #### **Steps of making a neural network**
#
# 1. Import and split the data into a train/validation set
# 2. Determine the dimensions of the data
# 3. Initialize the network model
# 4. Add an input layer
# 5. Add the hidden layers
# 6. Add the output layer
# 7. Fit the model
# 8. Evaluate the model

# %% [markdown]
# #### **Step #1: Import and split the data into a train/validation set**
#
# The first step is to import and pre-process the data. **Independently**, import, pre-process the data, and split it into a training and validation set.

# %%
# Select the directory where the data is saved
data_dir = 'alien_or_predator/'

dls = ImageDataLoaders.from_folder(
    data_dir,
    train='train',
    valid='validation',
    shuffle_train=True, # shuffle train
    item_tfms=Resize(128), # item transforms
    bs=8, # batch size
    device=device, # tell to use GPU if available
    pin_memory=True # To optimize GPU memory use
)

dls.show_batch()

# %% [markdown]
# #### **Step #2: Determine the input shape of the data**
# **This step is given to you. Run the cell below.**

# %%
# Get one batch of images and labels from the training set
images, labels = dls.train.one_batch()

# Get the first image from the batch
first_image = images[0]

# Print the shape of the first image
print("Image size (C x H x W):", first_image.shape)
# Out:
# Image size (C x H x W): torch.Size([3, 128, 128])

# %% [markdown]
# #### **Steps #3-6: Building the Neural Network**
#
# **Independently**, add the following layers:
# * A flattened input layer with the appropriate input dimensions
# * A hidden layer with 512 neurons and ReLU activation
# * A hidden layer with 256 neurons and ReLU activation
# * An output layer with one neuron (for binary classification) and sigmoid activation

# %%
# Define the neural network architecture
model = nn.Sequential(
    # ADD LAYER HERE
)

# %% [markdown]
# ##### **Solution**

# %%
# Define the neural network architecture
model = nn.Sequential(
    nn.Flatten(),
    nn.Linear(3 * 128 * 128, 512),
    nn.ReLU(),
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Linear(256, 1),
    nn.Sigmoid() # Add sigmoid for binary classification problems
)

# %% [markdown]
# Print a summary of the model to take a look at how many model parameters we have.
#
# **The code has been provided for you, run the cell below.**

# %%
summary(model.to(device), (3,128,128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                [-1, 49152]               0
#             Linear-2                  [-1, 512]      25,166,336
#               ReLU-3                  [-1, 512]               0
#             Linear-4                  [-1, 256]         131,328
#               ReLU-5                  [-1, 256]               0
#             Linear-6                    [-1, 1]             257
#            Sigmoid-7                    [-1, 1]               0
# ================================================================
# Total params: 25,297,921
# Trainable params: 25,297,921
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 0.39
# Params size (MB): 96.50
# Estimated Total Size (MB): 97.08
# ----------------------------------------------------------------

# %% [markdown]
# #### **Step #7: Training the Neural Network**
#
# **Independently**, train the model. Unfortunately, PyTorch and fast.ai do not supply an accuracy function for binary_classification, so we have provided one for you.
#
# We will use `BCELossFlat()` for the loss function (BCE stands for binary crossentropy), and `binary_accuracy` as the evaluation metric.
#
# For the fit, we will use 10 epochs and a learning rate of 0.0002.

# %%
# Define binary accuracy
def binary_accuracy(y_pred, y_true):
    y_pred = (y_pred.squeeze() > 0.5).float()
    return (y_pred == y_true).float().mean()


loss_func = # FILL IN CODE HERE

learn = Learner(
    dls,
    model,
    loss_func=# FILL IN CODE HERE,
    metrics=# FILL IN CODE HERE,
    opt_func=Adam) # We are going to use the Adam optimizer

# Train the model
# FILL IN CODE HERE

# %% [markdown]
# ###### **Solution**

# %%
# Define binary accuracy
def binary_accuracy(y_pred, y_true):
    # Output 0 if y_pred <= 0.5 and 1 if y_pred is > 0.5
    y_pred = (y_pred.squeeze() > 0.5).float()
    # Returns accuracy
    return (y_pred == y_true).float().mean()

loss_func = BCELossFlat()

learn = Learner(dls,
                model,
                loss_func=loss_func,
                metrics=binary_accuracy,
                opt_func=Adam)

# Train the model
learn.fit(10, lr=0.0002)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>binary_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.688395</td>
#       <td>0.630506</td>
#       <td>0.665000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.691143</td>
#       <td>0.700573</td>
#       <td>0.590000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.660909</td>
#       <td>0.643987</td>
#       <td>0.625000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.633915</td>
#       <td>0.635696</td>
#       <td>0.640000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.614963</td>
#       <td>0.698833</td>
#       <td>0.590000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.594604</td>
#       <td>0.654871</td>
#       <td>0.610000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.584969</td>
#       <td>0.662505</td>
#       <td>0.640000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.576765</td>
#       <td>0.606627</td>
#       <td>0.680000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.585555</td>
#       <td>0.688000</td>
#       <td>0.610000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.571805</td>
#       <td>0.603680</td>
#       <td>0.640000</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Step #8: Evaluate the Model**

# %% [markdown]
# **Independently**, print the accuracy and visualize the predictions. Fill in the code below.

# %%
# Calculate training accuracy
train_loss, train_accuracy = # FILL IN CODE HERE
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = # FILL IN CODE HERE
print(f"Validation accuracy: {valid_accuracy:.4f}")

# %% [markdown]
# ###### **Solution**

# %%
# Calculate training accuracy
train_loss, train_accuracy = learn.validate(dl=dls.train)
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = learn.validate(dl=dls.valid)
print(f"Validation accuracy: {valid_accuracy:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Training accuracy: 0.7151
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Validation accuracy: 0.6400

# %% [markdown]
# **Reflect**: As you see the model did not perform that well. Even though Deep Learning is preferred to traditional Machine Learning models, it still struggles to recognize the input image. Let's see if **Convolutional Neural Networks** can do better.

# %% [markdown]
# <a name="p1.2"></a>
#
# ### **Part 1.2: Classifying Images with Convolutional Neural Networks**
# ---
#
# The steps for making a convolutional neural network are the same. The only difference is we now have two new types of  special layers in our toolkit: the **convolutional layer** and the **max pooling layer**.

# %% [markdown]
# #### **Steps #3-6: Building the Neural Network**
#
# **Together**, we are going to create a CNN with four "blocks". Let's start with the first one.
#
# We define a convolutional layer using  `nn.Conv2d(in_channels, out_channels,kernel_size,padding)`.
#
# * `in_channels` is the input number of channels. For the input layer this will be `3` for the three color channels RGB.
# * `out_channels` is the number of channels we decide to output, these are sometimes called filter or kernels as well.
# * `kernel_size` is the size of the kernel. For example, `(2,2)`.
# * `padding` is how much we want to pad the input.
#
# Add a ReLU activation layer after.

# %%
# Initialize the model

# Add the first convolutional layer

# Add ReLU activation

# %% [markdown]
# ##### **Solution**

# %%
# Initialize the model
model = nn.Sequential()

# Add the first convolutional layer
model.add_module('block1_conv', nn.Conv2d(3, 32, kernel_size=3, padding=1))

# Add ReLU activation
model.add_module('block1_activation', nn.ReLU())

# %% [markdown]
# Remember that every convolutional layer will be followed by a max pooling layer. The function to add this layer is `nn.MaxPool2d(pool_size)`.
#
# **Together**, let's add a max pooling layer with a pool size of 2x2 to the first convolutional block.

# %%
# Add a max pooling layer

# %% [markdown]
# ##### **Solution**

# %%
# Add a max pooling layer
model.add_module('block1_pool',nn.MaxPool2d(2, 2))

# %% [markdown]
# **Together**, let's add the second block with the following layers:
#
# * A convolutional layer with 64 output channels, a `kernel_size=3`, and `padding=1`.
# * A ReLU activation layer
# * A max pool layer with 2x2 pool size

# %% [markdown]
# ###### **Solution**

# %%
# Add the first convolutional layer
model.add_module('block2_conv', nn.Conv2d(32, 64, kernel_size=3, padding=1))

# Add ReLU activation
model.add_module('block2_activation', nn.ReLU())

# Add a max pooling layer
model.add_module('block2_pool',nn.MaxPool2d(2, 2))

# %% [markdown]
# On your own, add two more blocks with the following parameters:
#
# Block 3:
# * A convolutional layer with 128 output channels, a `kernel_size=3`, and `padding=1`.
# * A ReLU activation layer
# * A max pool layer with 2x2 pool size
#
#
# Block 4:
# * A convolutional layer with 256 output channels, a `kernel_size=3`, and `padding=1`.
# * A ReLU activation layer
# * A max pool layer with 2x2 pool size

# %% [markdown]
# ###### **Solution**

# %%
model.add_module('block3_conv', nn.Conv2d(64, 128, kernel_size=3, padding=1))
model.add_module('block3_activation', nn.ReLU())
model.add_module('block3_pool',nn.MaxPool2d(2, 2))

model.add_module('block4_conv', nn.Conv2d(128, 256, kernel_size=3, padding=1))
model.add_module('block4_activation', nn.ReLU())
model.add_module('block4_pool',nn.MaxPool2d(2, 2))

# %% [markdown]
# **Together**, we are going to flatten the output, and add a linear layer with 512 neurons and ReLU activation. What is the input size for the linear layer?

# %% [markdown]
# ###### **Solution**

# %%
model.add_module('flatten', nn.Flatten())
model.add_module('linear1', nn.Linear(256*8*8,512))
model.add_module('linear1_activation', nn.ReLU())

# %% [markdown]
# On your own, add
# * one more linear layer with 256 neurons and ReLU activation
# * an output layer with one neuron and Sigmoid activation

# %% [markdown]
# ###### **Solution**

# %%
model.add_module('linear2', nn.Linear(512, 256))
model.add_module('linear2_activation', nn.ReLU())
model.add_module('output', nn.Linear(256, 1))
model.add_module('output_activation', nn.Sigmoid())

# %% [markdown]
# Let's take a look at the parameters in our model.
#
# <br>
#
# ##### ***STOP!* Answer the following question: Do you think there will be more parameters to train or fewer parameters than for the fully connected network in Part 1?**

# %%
summary(model.to(device), (3,128,128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 128, 128]             896
#               ReLU-2         [-1, 32, 128, 128]               0
#          MaxPool2d-3           [-1, 32, 64, 64]               0
#             Conv2d-4           [-1, 64, 64, 64]          18,496
#               ReLU-5           [-1, 64, 64, 64]               0
#          MaxPool2d-6           [-1, 64, 32, 32]               0
#             Conv2d-7          [-1, 128, 32, 32]          73,856
#               ReLU-8          [-1, 128, 32, 32]               0
#          MaxPool2d-9          [-1, 128, 16, 16]               0
#            Conv2d-10          [-1, 256, 16, 16]         295,168
#              ReLU-11          [-1, 256, 16, 16]               0
#         MaxPool2d-12            [-1, 256, 8, 8]               0
#           Flatten-13                [-1, 16384]               0
#            Linear-14                  [-1, 512]       8,389,120
#              ReLU-15                  [-1, 512]               0
#            Linear-16                  [-1, 256]         131,328
#              ReLU-17                  [-1, 256]               0
#            Linear-18                    [-1, 1]             257
#           Sigmoid-19                    [-1, 1]               0
# ================================================================
# Total params: 8,909,121
# Trainable params: 8,909,121
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 17.01
# Params size (MB): 33.99
# Estimated Total Size (MB): 51.18
# ----------------------------------------------------------------

# %% [markdown]
# #### **Step #7: Training the Neural Network**

# %%
loss_func = # FILL IN CODE HERE

learn = Learner(
    dls,
    model,
    loss_func=# FILL IN CODE HERE,
    metrics=# FILL IN CODE HERE,
    opt_func=Adam) # We are going to use the Adam optimizer

# Train the model

# %% [markdown]
# ###### **Solution**

# %%
loss_func = BCELossFlat()

learn = Learner(dls,
                model,
                loss_func=loss_func,
                metrics=binary_accuracy,
                opt_func=Adam)

# Train the model
learn.fit(10, lr=0.0002)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>binary_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.694210</td>
#       <td>0.693172</td>
#       <td>0.500000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.689142</td>
#       <td>0.670512</td>
#       <td>0.530000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.673959</td>
#       <td>0.622900</td>
#       <td>0.645000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.657089</td>
#       <td>0.646830</td>
#       <td>0.620000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.587650</td>
#       <td>0.548848</td>
#       <td>0.700000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.551986</td>
#       <td>0.558221</td>
#       <td>0.680000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.526940</td>
#       <td>0.560025</td>
#       <td>0.725000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.506735</td>
#       <td>0.526175</td>
#       <td>0.720000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.497529</td>
#       <td>0.527000</td>
#       <td>0.720000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.509750</td>
#       <td>0.510602</td>
#       <td>0.730000</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Step #8: Evaluate the Model**
# **Together**, let's print the accuracy and visualize the predictions.

# %%
# Calculate training accuracy
train_loss, train_accuracy = # FILL IN CODE HERE
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = # FILL IN CODE HERE
print(f"Validation accuracy: {valid_accuracy:.4f}")

# %% [markdown]
# ###### **Solution**

# %%
# Calculate training accuracy
train_loss, train_accuracy = learn.validate(dl=dls.train)
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = learn.validate(dl=dls.valid)
print(f"Validation accuracy: {valid_accuracy:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Training accuracy: 0.7980
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Validation accuracy: 0.7300

# %% [markdown]
# <a name="p2"></a>
#
# ---
# ## **Part 2: [ADDITIONAL PRACTICE] Chihuahua or Muffin?**
# ---
#
# **Chihuahua or Muffin?** This is a classic example in Computer Vision where you can easily confuse a deep learning model to misclassify a blueberry muffin with a chihuahua. In this section, we train a DNN model to differentiate between two classes of images: Chihuahua and Muffin.
#
#
# ![chihuahua_or_muffin.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **Part 2.1: Building a Deep Neural Network for Image Classification**
# ---
#
# In this section, you will follow the steps above to build, train, and evaluate a DNN model for binary image classification.

# %% [markdown]
# **Run the code below to download the raw data.**

# %%
# !gdown 1-LmbZqBxEFMp3KZc7X1YobqolXAExZc0
# !unzip -qq -n chihuahua_or_muffin.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-LmbZqBxEFMp3KZc7X1YobqolXAExZc0
# To: /home/studio-lab-user/sagemaker-studiolab-notebooks/chihuahua_or_muffin.zip
# 100%|████████████████████████████████████████| 512M/512M [00:07<00:00, 66.3MB/s]

# %% [markdown]
# #### **Step #1: Import and split the data into a train/validation set**
#
# The first step is to import and pre-process the data. This code is provided for you.

# %%
# Select the directory where the data is saved
data_dir = 'chihuahua_or_muffin/'

dls = ImageDataLoaders.from_folder(data_dir,
                                   train='train',
                                   valid='validation',
                                   shuffle_train=True,
                                   item_tfms=Resize(128), # item transforms
                                   bs=64, # batch size
                                   device=device, # tell to use GPU if available
                                   pin_memory=True # To optimize GPU memory use
                                   )

dls.show_batch()

# %% [markdown]
# #### **Step #2: Determine the input shape of the data**
#
# **This step is given to you. Run the cell below.**

# %%
# Get one batch of images and labels from the training set
images, labels = dls.train.one_batch()

# Get the first image from the batch
first_image = images[0]

# Print the shape of the first image
print("Image size (C x H x W):", first_image.shape)
# Out:
# Image size (C x H x W): torch.Size([3, 128, 128])

# %% [markdown]
# #### **Steps #3-6: Building the Neural Network**

# %% [markdown]
# Add the appropriate input layer, then two hidden layers: one with 1024 neurons and another with 512 neurons. Use ReLU for the hidden layers and sigmoid activation for the output layer.

# %%
# Define the neural network architecture
model = nn.Sequential(
    # ADD LAYER HERE
)

# %% [markdown]
# ##### **Solution**

# %%
# Define the neural network architecture
model = nn.Sequential(
    nn.Flatten(),
    nn.Linear(3 * 128 * 128, 1024),
    nn.ReLU(),
    nn.Linear(1024, 512),
    nn.ReLU(),
    nn.Linear(512, 1),
    nn.Sigmoid() # Add sigmoid for binary classification problems
)

# %% [markdown]
# Let's print a summary of the model to take a look at how many model parameters we have. **The code has been provided for you, run the cell below.** If done correctly, you should see 50,857,985 total parameters.

# %%
summary(model.to(device), (3,128,128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                [-1, 49152]               0
#             Linear-2                 [-1, 1024]      50,332,672
#               ReLU-3                 [-1, 1024]               0
#             Linear-4                  [-1, 512]         524,800
#               ReLU-5                  [-1, 512]               0
#             Linear-6                    [-1, 1]             513
#            Sigmoid-7                    [-1, 1]               0
# ================================================================
# Total params: 50,857,985
# Trainable params: 50,857,985
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 0.40
# Params size (MB): 194.01
# Estimated Total Size (MB): 194.59
# ----------------------------------------------------------------

# %% [markdown]
# #### **Step #7: Training the Neural Network**

# %% [markdown]
# Write the code to train the model. Use `BCELossFlat()` for the loss function (BCE stands for binary crossentropy), and `binary_accuracy` as the evaluation metric.
#
# For the fit, use 10 epochs and a learning rate of 0.0001.
#
# **This dataset is much larger than the Alien vs. Predator dataset, so it will take longer to train.**

# %%
loss_func = # FILL IN CODE HERE

learn = Learner(
    dls,
    model,
    loss_func=# FILL IN CODE HERE,
    metrics=# FILL IN CODE HERE,
    opt_func=Adam) # We are going to use the Adam optimizer

# Train the model

# %% [markdown]
# ###### **Solution**

# %%
loss_func = BCELossFlat()

learn = Learner(dls,
                model,
                loss_func=loss_func,
                metrics=binary_accuracy,
                opt_func=Adam)

# Train the model
learn.fit(5, lr=0.0001)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>binary_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.651831</td>
#       <td>0.605927</td>
#       <td>0.653716</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.617988</td>
#       <td>0.592906</td>
#       <td>0.701858</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.592021</td>
#       <td>0.569370</td>
#       <td>0.722128</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.580151</td>
#       <td>0.538393</td>
#       <td>0.739865</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.558774</td>
#       <td>0.582165</td>
#       <td>0.691723</td>
#       <td>00:29</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Step #8: Evaluate the Model**

# %% [markdown]
# Let's print the accuracy and visualize the predictions.
#
# ---

# %%
# Calculate training accuracy
train_loss, train_accuracy = # FILL IN CODE HERE
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = # FILL IN CODE HERE
print(f"Validation accuracy: {valid_accuracy:.4f}")

# %% [markdown]
# ###### **Solution**

# %%
# Calculate training accuracy
train_loss, train_accuracy = learn.validate(dl=dls.train)
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = learn.validate(dl=dls.valid)
print(f"Validation accuracy: {valid_accuracy:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Training accuracy: 0.6952
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Validation accuracy: 0.6917

# %% [markdown]
# ### **Part 2.2: Building a Convolutional Neural Network for Image Classification**
# ---

# %% [markdown]
# #### **Steps #3-6: Building the Neural Network**
#
# Create a CNN with four blocks. The parameters to use are as follows:
#
#
# Block 1:
# * A convolutional layer with 64 output channels, a `kernel_size=3`, and `padding=1`.
# * A ReLU activation layer
# * A max pool layer with 2x2 pool size
#
# Block 2:
# * A convolutional layer with 128 output channels, a `kernel_size=3`, and `padding=1`.
# * A ReLU activation layer
# * A max pool layer with 2x2 pool size
#
#
# Block 3:
# * A convolutional layer with 256 output channels, a `kernel_size=3`, and `padding=1`.
# * A ReLU activation layer
# * A max pool layer with 2x2 pool size
#
#
# Block 4:
# * A convolutional layer with 512 output channels, a `kernel_size=3`, and `padding=1`.
# * A ReLU activation layer
# * A max pool layer with 2x2 pool size
#
# Then, add the following layers:
# * A flatten layer
# * A linear layer with the appropriate input shape with 1024 neurons and ReLU activation
# * Another linear layer with 512 neurons and ReLU activation
# * An output layer with one neuron and sigmoid activation.

# %%
# Initialize the model and add layers

# %% [markdown]
# ##### **Solution**

# %%
model = nn.Sequential()

model.add_module('block1_conv', nn.Conv2d(3, 64, kernel_size=3, padding=1))
model.add_module('block1_activation', nn.ReLU())
model.add_module('block1_pool',nn.MaxPool2d(2, 2))

model.add_module('block2_conv', nn.Conv2d(64, 128, kernel_size=3, padding=1))
model.add_module('block2_activation', nn.ReLU())
model.add_module('block2_pool',nn.MaxPool2d(2, 2))

model.add_module('block3_conv', nn.Conv2d(128, 256, kernel_size=3, padding=1))
model.add_module('block3_activation', nn.ReLU())
model.add_module('block3_pool',nn.MaxPool2d(2, 2))

model.add_module('block4_conv', nn.Conv2d(256, 512, kernel_size=3, padding=1))
model.add_module('block4_activation', nn.ReLU())
model.add_module('block4_pool',nn.MaxPool2d(2, 2))

model.add_module('flatten', nn.Flatten())
model.add_module('linear1', nn.Linear(512*8*8,1024))
model.add_module('linear1_activation', nn.ReLU())

model.add_module('linear2', nn.Linear(1024, 512))
model.add_module('linear2_activation', nn.ReLU())
model.add_module('output', nn.Linear(512, 1))
model.add_module('output_activation', nn.Sigmoid())

# %% [markdown]
# Let's take a look at the parameters in our model. If done correctly, you should see 35,631,745 total parameters.

# %%
summary(model.to(device), (3,128,128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 128, 128]           1,792
#               ReLU-2         [-1, 64, 128, 128]               0
#          MaxPool2d-3           [-1, 64, 64, 64]               0
#             Conv2d-4          [-1, 128, 64, 64]          73,856
#               ReLU-5          [-1, 128, 64, 64]               0
#          MaxPool2d-6          [-1, 128, 32, 32]               0
#             Conv2d-7          [-1, 256, 32, 32]         295,168
#               ReLU-8          [-1, 256, 32, 32]               0
#          MaxPool2d-9          [-1, 256, 16, 16]               0
#            Conv2d-10          [-1, 512, 16, 16]       1,180,160
#              ReLU-11          [-1, 512, 16, 16]               0
#         MaxPool2d-12            [-1, 512, 8, 8]               0
#           Flatten-13                [-1, 32768]               0
#            Linear-14                 [-1, 1024]      33,555,456
#              ReLU-15                 [-1, 1024]               0
#            Linear-16                  [-1, 512]         524,800
#              ReLU-17                  [-1, 512]               0
#            Linear-18                    [-1, 1]             513
#           Sigmoid-19                    [-1, 1]               0
# ================================================================
# Total params: 35,631,745
# Trainable params: 35,631,745
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 34.02
# Params size (MB): 135.92
# Estimated Total Size (MB): 170.14
# ----------------------------------------------------------------

# %% [markdown]
# #### **Step #7: Training the Neural Network**
#
#
# Use the same parameters as Part 3.1.

# %%
loss_func =

learn = Learner(
    dls,
    model,
    loss_func=# FILL IN CODE HERE,
    metrics=# FILL IN CODE HERE,
    opt_func=Adam) # We are going to use the Adam optimizer

# Train the model

# %% [markdown]
# ###### **Solution**

# %%
loss_func = BCELossFlat()

learn = Learner(dls,
                model,
                loss_func=loss_func,
                metrics=binary_accuracy,
                opt_func=Adam)

learn.fit(5, lr=0.0001)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>binary_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.604279</td>
#       <td>0.499356</td>
#       <td>0.771959</td>
#       <td>01:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.525511</td>
#       <td>0.433712</td>
#       <td>0.815878</td>
#       <td>01:35</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.444348</td>
#       <td>0.360392</td>
#       <td>0.852196</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.363677</td>
#       <td>0.266611</td>
#       <td>0.909628</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.302396</td>
#       <td>0.237861</td>
#       <td>0.923986</td>
#       <td>01:33</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Step #8: Evaluate the Model**

# %% [markdown]
# Let's print the accuracy and visualize the predictions.

# %%
# Calculate training accuracy
train_loss, train_accuracy = # FILL IN CODE HERE
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = # FILL IN CODE HERE
print(f"Validation accuracy: {valid_accuracy:.4f}")

# %% [markdown]
# ###### **Solution**

# %%
# Calculate training accuracy
train_loss, train_accuracy = learn.validate(dl=dls.train)
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = learn.validate(dl=dls.valid)
print(f"Validation accuracy: {valid_accuracy:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Training accuracy: 0.9073
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Validation accuracy: 0.9240

# %% [markdown]
# <a name="p3"></a>
#
# ## **Part 3: Advanced Deep Learning Techniques**
# ---
#
# In this section, we will revisit the Alien vs. Predator dataset. It is a challenging dataset because it is smaller than we would prefer for training deep neural networks. However, there are some advanced tools we can use to improve the model performance over what we were able to achieve last time.

# %% [markdown]
# <a name="p3.1"></a>
#
# ### **Part 3.1: Data Augmentation**
#
# ---

# %% [markdown]
# #### **Step #1: Import and split the data into a train/validation set**
#
# **Together**, we will import, pre-process the data, and split it into a training and validation set. We will use the validation set to help us improve the model in the next section.
#
# This time, we'll add data augmentation by adding some item and batch transforms when we build our ImageDataLoader.

# %% [markdown]
# #### **Problem #3.1**
#
# **Together**, use the following parameters when building the ImageDataLoader:
#
# * Resize all images to 128x128
# * Apply default data augmentation using `aug_transforms()`

# %%
# Select the directory where the data is saved
data_dir = 'alien_or_predator/'

dls = ImageDataLoaders.from_folder(
    data_dir,
    train='train',
    valid='validation',
    shuffle_train=True, # shuffle train
    item_tfms=#FILL IN CODE HERE, # item transforms
    batch_tfms=#FILL IN CODE HERE, # add data augmentation
    bs=8, # batch size
    device=device, # tell to use GPU if available
    pin_memory=True # To optimize GPU memory use
)

dls.show_batch(nrows=2, ncols=4)

# %% [markdown]
# ###### **Solution**

# %%
# Select the directory where the data is saved
data_dir = 'alien_or_predator/'

dls = ImageDataLoaders.from_folder(
    data_dir,
    train='train',
    valid='validation',
    shuffle_train=True, # shuffle train
    item_tfms=Resize(128), # item transforms
    batch_tfms=aug_transforms(), # add data augmentation
    bs=8, # batch size
    device=device, # tell to use GPU if available
    pin_memory=True # To optimize GPU memory use
)

dls.show_batch(nrows=2, ncols=4)

# %% [markdown]
# #### **Problem #3.2**
#
# **Together**, let's customize the data augmentation transforms with the following parameters:
#
# * `do_flip=True`
# * `flip_vert=False`
# * `max_rotate=30.0`

# %%
batch_tfms=aug_transforms(# FILL IN CODE HERE

dls = ImageDataLoaders.from_folder(
    data_dir,
    train='train',
    valid='validation',
    shuffle_train=True, # shuffle train
    item_tfms=Resize(128), # item transforms
    batch_tfms=#FILL IN CODE HERE, # add data augmentation
    bs=8, # batch size
    device=device, # tell to use GPU if available
    pin_memory=True # To optimize GPU memory use
)

dls.show_batch(nrows=2, ncols=4)

# %% [markdown]
# ###### **Solution**

# %%
batch_tfms=aug_transforms(do_flip=True, flip_vert=False, max_rotate=30.0)

dls = ImageDataLoaders.from_folder(
    data_dir,
    train='train',
    valid='validation',
    shuffle_train=True, # shuffle train
    item_tfms=Resize(128), # item transforms
    batch_tfms=batch_tfms, # add data augmentation
    bs=8, # batch size
    device=device, # tell to use GPU if available
    pin_memory=True, # To optimize GPU memory use
)

dls.show_batch(nrows=2, ncols=4)

# %% [markdown]
# ---
# #### **Try Steps #2 - #8 on your own!**
# ---

# %% [markdown]
# #### **Step #2: Determine the input shape of the data**
# **This step is given to you. Run the cell below.**

# %%
# Get one batch of images and labels from the training set
images, labels = dls.train.one_batch()

# Get the first image from the batch
first_image = images[0]

# Print the shape of the first image
print("Image size (C x H x W):", first_image.shape)
# Out:
# Image size (C x H x W): torch.Size([3, 128, 128])

# %% [markdown]
# #### **Steps #3-6: Building the Neural Network**

# %% [markdown]
# **Independently**, build a CNN with the following parameters:
#
# Block 1:
# * A convolutional layer with 32 output channels, a `kernel_size=3`, and `padding=1`.
# * A ReLU activation layer
# * A max pool layer with 2x2 pool size
#
#
# Block 2:
# * A convolutional layer with 64 output channels, a `kernel_size=3`, and `padding=1`.
# * A ReLU activation layer
# * A max pool layer with 2x2 pool size
#
# Block 3:
# * A convolutional layer with 128 output channels, a `kernel_size=3`, and `padding=1`.
# * A ReLU activation layer
# * A max pool layer with 2x2 pool size
#
#
# Block 4:
# * A convolutional layer with 256 output channels, a `kernel_size=3`, and `padding=1`.
# * A ReLU activation layer
# * A max pool layer with 2x2 pool size
#
# Finally, add:
# * A flatten layer
# * A linear layer with 512 neurons and ReLU activation
# * Another linear layer with 256 neurons and ReLU activation
# * An output layer with one neuron and Sigmoid activation

# %%
# Define the neural network architecture
model = # WRITE YOUR CODE HERE

# %% [markdown]
# ##### **Solution**

# %%
# Initialize the model
model = nn.Sequential()

model.add_module('block1_conv', nn.Conv2d(3, 32, kernel_size=3, padding=1))
model.add_module('block1_activation', nn.ReLU())
model.add_module('block1_pool',nn.MaxPool2d(2, 2))

model.add_module('block2_conv', nn.Conv2d(32, 64, kernel_size=3, padding=1))
model.add_module('block2_activation', nn.ReLU())
model.add_module('block2_pool',nn.MaxPool2d(2, 2))

model.add_module('block3_conv', nn.Conv2d(64, 128, kernel_size=3, padding=1))
model.add_module('block3_activation', nn.ReLU())
model.add_module('block3_pool',nn.MaxPool2d(2, 2))

model.add_module('block4_conv', nn.Conv2d(128, 256, kernel_size=3, padding=1))
model.add_module('block4_activation', nn.ReLU())
model.add_module('block4_pool',nn.MaxPool2d(2, 2))

model.add_module('flatten', nn.Flatten())
model.add_module('linear1', nn.Linear(256*8*8,512))
model.add_module('linear1_activation', nn.ReLU())

model.add_module('linear2', nn.Linear(512, 256))
model.add_module('linear2_activation', nn.ReLU())
model.add_module('output', nn.Linear(256, 1))
model.add_module('output_activation', nn.Sigmoid())

# %% [markdown]
# #### **Step #7: Training the Neural Network**
# **Independently**, train the neural network. Use `BCELossFlat()` for the loss function (BCE stands for binary crossentropy), and `binary_accuracy` as the evaluation metric.
#
# For the fit, we will use 10 epochs and a learning rate of 0.0002.

# %%
loss_func = # FILL IN CODE HERE

learn = Learner(
    dls,
    model,
    loss_func=# FILL IN CODE HERE,
    metrics=# FILL IN CODE HERE,
    opt_func=Adam) # We are going to use the Adam optimizer

# Train the model
# FILL IN CODE HERE

learn.recorder.plot_loss()

# %% [markdown]
# ###### **Solution**

# %%
loss_func = BCELossFlat()

learn = Learner(dls,
                model,
                loss_func=loss_func,
                metrics=binary_accuracy,
                opt_func=Adam)

# Train the model
learn.fit(10, lr=0.0002)

learn.recorder.plot_loss()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>binary_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.694847</td>
#       <td>0.691802</td>
#       <td>0.500000</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.687300</td>
#       <td>0.659460</td>
#       <td>0.590000</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.634896</td>
#       <td>0.571756</td>
#       <td>0.680000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.606302</td>
#       <td>0.577123</td>
#       <td>0.695000</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.565263</td>
#       <td>0.564419</td>
#       <td>0.685000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.528031</td>
#       <td>0.584764</td>
#       <td>0.710000</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.521688</td>
#       <td>0.498213</td>
#       <td>0.745000</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.540097</td>
#       <td>0.503021</td>
#       <td>0.740000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.527194</td>
#       <td>0.484634</td>
#       <td>0.765000</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.517147</td>
#       <td>0.460768</td>
#       <td>0.785000</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Step #8: Evaluate the Model**
# **Independently**, print the accuracy and visualize the predictions.

# %%
# Calculate training accuracy
train_loss, train_accuracy = # FILL IN CODE HERE
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = # FILL IN CODE HERE
print(f"Validation accuracy: {valid_accuracy:.4f}")

# %% [markdown]
# ###### **Solution**

# %%
# Calculate training accuracy
train_loss, train_accuracy = learn.validate(dl=dls.train)
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = learn.validate(dl=dls.valid)
print(f"Validation accuracy: {valid_accuracy:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Training accuracy: 0.7907
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Validation accuracy: 0.7850

# %% [markdown]
# ---
#
# <center>
#
# #### **Back to lecture**
#
# ---

# %% [markdown]
# <a name="p3.2"></a>
#
# ### **Part 3.2: Dropout Layers**
#
# ---

# %% [markdown]
# #### **Steps #3-6: Building the Neural Network**
# **Independently,** build a neural network. Use the same neural network from Part 3.1, but this time add a dropout layer with `p=0.5` after the first convolutional layer and the first two linear layers. Remember, for the convolutional layer you'll use `nn.Dropout2d()`, and for the linear layers you'll use `nn.Dropout()`.

# %%
# Define the neural network architecture
model = # WRITE YOUR CODE HERE

# %% [markdown]
# ##### **Solution**

# %%
model = nn.Sequential()

model.add_module('block1_conv', nn.Conv2d(3, 32, kernel_size=3, padding=1))
model.add_module('block1_dropout', nn.Dropout2d(p=0.5))
model.add_module('block1_activation', nn.ReLU())
model.add_module('block1_pool',nn.MaxPool2d(2, 2))

model.add_module('block2_conv', nn.Conv2d(32, 64, kernel_size=3, padding=1))
#model.add_module('block2_dropout', nn.Dropout2d(p=0.5))
model.add_module('block2_activation', nn.ReLU())
model.add_module('block2_pool',nn.MaxPool2d(2, 2))

model.add_module('block3_conv', nn.Conv2d(64, 128, kernel_size=3, padding=1))
#model.add_module('block3_dropout', nn.Dropout2d(p=0.5))
model.add_module('block3_activation', nn.ReLU())
model.add_module('block3_pool',nn.MaxPool2d(2, 2))

model.add_module('block4_conv', nn.Conv2d(128, 256, kernel_size=3, padding=1))
#model.add_module('block4_dropout', nn.Dropout2d(p=0.5))
model.add_module('block4_activation', nn.ReLU())
model.add_module('block4_pool',nn.MaxPool2d(2, 2))

model.add_module('flatten', nn.Flatten())
model.add_module('linear1', nn.Linear(256*8*8,512))
model.add_module('dropout1', nn.Dropout(p=0.5))
model.add_module('linear1_activation', nn.ReLU())

model.add_module('linear2', nn.Linear(512, 256))
model.add_module('dropout2', nn.Dropout(p=0.5))
model.add_module('linear2_activation', nn.ReLU())
model.add_module('output', nn.Linear(256, 1))
model.add_module('output_activation', nn.Sigmoid())

# %% [markdown]
# #### **Step #7: Training the Neural Network**
#
# **Independently**, train the model. Unfortunately, PyTorch and fast.ai do not supply an accuracy function for binary_classification, so we have provided one for you.
#
# We will use `BCELossFlat()` for the loss function (BCE stands for binary crossentropy), and `binary_accuracy` as the evaluation metric.
#
# For the fit, we will use 15 epochs and a learning rate of 0.0002.

# %%
loss_func = # FILL IN CODE HERE

learn = Learner(
    dls,
    model,
    loss_func=# FILL IN CODE HERE,
    metrics=# FILL IN CODE HERE,
    opt_func=Adam) # We are going to use the Adam optimizer

# Train the model
# FILL IN CODE HERE

learn.recorder.plot_loss()

# %% [markdown]
# ###### **Solution**

# %%
loss_func = BCELossFlat()

learn = Learner(dls,
                model,
                loss_func=loss_func,
                metrics=binary_accuracy,
                opt_func=Adam)

# Train the model
learn.fit(15, lr=0.0002)

learn.recorder.plot_loss()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>binary_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.536968</td>
#       <td>0.529916</td>
#       <td>0.745000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.557098</td>
#       <td>0.530575</td>
#       <td>0.750000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.548658</td>
#       <td>0.518766</td>
#       <td>0.780000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.552864</td>
#       <td>0.538399</td>
#       <td>0.765000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.501650</td>
#       <td>0.584114</td>
#       <td>0.705000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.517101</td>
#       <td>0.553302</td>
#       <td>0.745000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.513565</td>
#       <td>0.510885</td>
#       <td>0.760000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.500469</td>
#       <td>0.550045</td>
#       <td>0.765000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.478323</td>
#       <td>0.538410</td>
#       <td>0.775000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.484063</td>
#       <td>0.534991</td>
#       <td>0.760000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.476093</td>
#       <td>0.547688</td>
#       <td>0.740000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.473415</td>
#       <td>0.545729</td>
#       <td>0.775000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.480363</td>
#       <td>0.552491</td>
#       <td>0.790000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.475901</td>
#       <td>0.543926</td>
#       <td>0.770000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.468807</td>
#       <td>0.983307</td>
#       <td>0.780000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.476625</td>
#       <td>0.980454</td>
#       <td>0.780000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.463377</td>
#       <td>0.579324</td>
#       <td>0.760000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.473685</td>
#       <td>0.538941</td>
#       <td>0.775000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.472629</td>
#       <td>0.561232</td>
#       <td>0.750000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.449427</td>
#       <td>0.950385</td>
#       <td>0.775000</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Step #8: Evaluate the Model**
# **Independently**, print the accuracy and visualize the predictions.

# %%
# Calculate training accuracy
train_loss, train_accuracy = # FILL IN CODE HERE
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = # FILL IN CODE HERE
print(f"Validation accuracy: {valid_accuracy:.4f}")

# %% [markdown]
# ###### **Solution**

# %%
# Calculate training accuracy
train_loss, train_accuracy = learn.validate(dl=dls.train)
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = learn.validate(dl=dls.valid)
print(f"Validation accuracy: {valid_accuracy:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Training accuracy: 0.8140
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Validation accuracy: 0.7750

# %% [markdown]
# ---
#
# <center>
#
# #### **Back to lecture**
#
# ---

# %% [markdown]
# <a name="p3.3"></a>
#
# ### **Part 3.3: Using Pre-Trained Models**
#
# ---

# %% [markdown]
# #### **Step #3-6: Building the Neural Network**
#
#
# **Together**, instead of building our own CNN, we'll use a pre-trained model.
#
# After the Adaptive Max Pooling layer (which adapts to the size of the input, if the input image is a different size than the pre-trained model was originally trained on), add the following layers:
#
# * A Flatten layer
# * An output linear layer with an input of `num_out_features` and an output of `1`.
# * A sigmoid activation layer

# %%
from torchvision.models import resnet34
from torchvision.models.resnet import ResNet34_Weights

model = resnet34(weights=ResNet34_Weights.IMAGENET1K_V1)

# Create a new model head with an AdaptiveMaxPool2d layer and a linear layer
num_out_features = model.fc.in_features
new_head = nn.Sequential(nn.AdaptiveMaxPool2d(output_size=(1, 1)),
                         #ADD LAYERS HERE
                         )

# Replace the existing model head
model = nn.Sequential(*list(model.children())[:-2], new_head)

# %% [markdown]
# ##### **Solution**

# %%
from torchvision.models import resnet34
from torchvision.models.resnet import ResNet34_Weights

model = resnet34(weights=ResNet34_Weights.IMAGENET1K_V1)

# Create a new model head with an AdaptiveMaxPool2d layer and a linear layer
num_out_features = model.fc.in_features
new_head = nn.Sequential(nn.AdaptiveMaxPool2d(output_size=(1, 1)),
                         nn.Flatten(),
                         nn.Linear(num_out_features, 1),
                         nn.Sigmoid())

# Replace the existing model head
model = nn.Sequential(*list(model.children())[:-2], new_head)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 238MB/s]

# %% [markdown]
# #### **Step #7: Training the Neural Network**

# %% [markdown]
# Again, we will be using `BCELossFlat()` for the loss function (BCE stands for binary crossentropy), and `binary_accuracy` as the evaluation metric.
#
# For the fit, we suggest 5 epochs and a learning rate of 0.0001, but feel free to choose your own hyperparameters.
#
# We will have to use `learn.freeze()` after defining the `Learner` object to make sure we are only re-training the last layer and freezing the rest of the parameters from the pre-trained model.

# %%
loss_func = # FILL IN CODE HERE

learn = Learner(
    dls,
    model,
    loss_func=# FILL IN CODE HERE,
    metrics=# FILL IN CODE HERE,
    opt_func=Adam) # We are going to use the Adam optimizer

# Freeze all layers except the last one
learn.freeze()

# Train the model
# FILL IN CODE HERE

# %% [markdown]
# ###### **Solution**

# %%
learn = Learner(dls,
                model,
                metrics=binary_accuracy,
                loss_func=BCELossFlat(),
                opt_func=Adam)

# Freeze all layers except the last one
learn.freeze()

# Train the model
learn.fit(5, lr=0.0001)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>binary_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.380063</td>
#       <td>0.207707</td>
#       <td>0.915000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.225954</td>
#       <td>0.168052</td>
#       <td>0.925000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.119377</td>
#       <td>0.179714</td>
#       <td>0.935000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.123433</td>
#       <td>0.203260</td>
#       <td>0.945000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.106737</td>
#       <td>0.201158</td>
#       <td>0.910000</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Step #8: Evaluate the Model**

# %% [markdown]
# **Together**, let's print the accuracy and visualize the predictions.

# %%
# Calculate training accuracy
train_loss, train_accuracy = # FILL IN CODE HERE
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = # FILL IN CODE HERE
print(f"Validation accuracy: {valid_accuracy:.4f}")

# %% [markdown]
# <a name="p4"></a>
#
# ---
# ## **Part 4: [ADDITIONAL PRACTICE] Classifification of Dogs and Cats**
# ---
#
# In this section, you can choose what model and tools you want to use to achieve 85% accuracy on the Dogs and Cats dataset. This is a large dataset (it will not have the small-dataset problems of the Alien vs. Predator dataset). It will also take much longer to train, so keep that in mind when choosing hyperparameters like the number of epochs.

# %% [markdown]
# #### **Step #1: Import and split the data into a train/validation set**

# %%
path = untar_data(URLs.DOGS)
dls = ImageDataLoaders.from_folder(path,
                                   train='train',
                                   valid='valid',
                                   item_tfms = [Resize(128)],
                                   bs=64)
dls.show_batch(max_n=16, figsize=(9,9))

# %% [markdown]
# #### **Step #2: Determine the input shape of the data**
#
# **This step is given to you. Run the cell below.**

# %%
# Get one batch of images and labels from the training set
images, labels = dls.train.one_batch()

# Get the first image from the batch
first_image = images[0]

# Print the shape of the first image
print("Image size (C x H x W):", first_image.shape)
# Out:
# Image size (C x H x W): torch.Size([3, 128, 128])

# %% [markdown]
# #### **Steps #3-6: Building the Neural Network**

# %%
model = # BUILD YOUR MODEL HERE

# %% [markdown]
# ##### **Solution**

# %%
model = nn.Sequential(
    nn.Conv2d(3, 32, kernel_size=3, padding=1),
    nn.Dropout2d(p=0.5),
    nn.ReLU(),
    nn.MaxPool2d(2, 2),

    nn.Conv2d(32, 64, kernel_size=3, padding=1),
    nn.Dropout2d(p=0.5),
    nn.ReLU(),
    nn.MaxPool2d(2, 2),

    nn.Conv2d(64, 128, kernel_size=3, padding=1),
    nn.Dropout2d(p=0.5),
    nn.ReLU(),
    nn.MaxPool2d(2, 2),

    nn.Conv2d(128, 256, kernel_size=3, padding=1),
    nn.Dropout2d(p=0.5),
    nn.ReLU(),
    nn.MaxPool2d(2, 2),

    nn.Flatten(),
    nn.Linear(256 * 8 * 8, 512),
    nn.Dropout(p=0.5),
    nn.ReLU(),

    nn.Linear(512, 256),
    nn.Dropout(p=0.5),
    nn.ReLU(),

    nn.Linear(256, 1),
    nn.Sigmoid()
)

# %% [markdown]
# #### **Step #7: Training the Neural Network**

# %%
loss_func = # FILL IN CODE HERE

learn = Learner(
    dls,
    model,
    loss_func=# FILL IN CODE HERE,
    metrics=# FILL IN CODE HERE,
    opt_func=Adam) # We are going to use the Adam optimizer

# Train the model

# %% [markdown]
# ###### **Solution**

# %%
loss_func = BCELossFlat()

learn = Learner(dls,
                model,
                loss_func=loss_func,
                metrics=binary_accuracy,
                opt_func=Adam)

# Train the model
learn.fit(10, lr=0.001)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>binary_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.694058</td>
#       <td>0.693316</td>
#       <td>0.500000</td>
#       <td>02:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.692627</td>
#       <td>0.691334</td>
#       <td>0.537500</td>
#       <td>02:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.680006</td>
#       <td>0.667128</td>
#       <td>0.632500</td>
#       <td>02:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.663181</td>
#       <td>0.652550</td>
#       <td>0.648000</td>
#       <td>02:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.640509</td>
#       <td>0.614932</td>
#       <td>0.674000</td>
#       <td>02:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.626713</td>
#       <td>0.627447</td>
#       <td>0.651000</td>
#       <td>02:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.602521</td>
#       <td>0.600489</td>
#       <td>0.671000</td>
#       <td>02:12</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.597289</td>
#       <td>0.577075</td>
#       <td>0.709000</td>
#       <td>02:12</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.582235</td>
#       <td>0.576329</td>
#       <td>0.692000</td>
#       <td>02:12</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.574505</td>
#       <td>0.562064</td>
#       <td>0.715500</td>
#       <td>02:14</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Step #8: Evaluate the Model**
# Let's print the accuracy and visualize the predictions.

# %%
# Calculate training accuracy
train_loss, train_accuracy = # FILL IN CODE HERE
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = # FILL IN CODE HERE
print(f"Validation accuracy: {valid_accuracy:.4f}")

# %% [markdown]
# ###### **Solution**

# %%
# Calculate training accuracy
train_loss, train_accuracy = learn.validate(dl=dls.train)
print(f"Training accuracy: {train_accuracy:.4f}")

# Calculate validation accuracy
valid_loss, valid_accuracy = learn.validate(dl=dls.valid)
print(f"Validation accuracy: {valid_accuracy:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Training accuracy: 0.7255
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Validation accuracy: 0.7155

# %% [markdown]
# # End of notebook
# ---
# © 2023 The Coding School, All rights reserved
